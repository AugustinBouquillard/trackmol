# %%
# %load_ext autoreload
# %autoreload 2
from gratin.standard import train_model, load_model, plot_demo, get_predictions
import matplotlib.pyplot as plt
import socket
# Out:
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/umap/distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/umap/distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/umap/distances.py:1086: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/umap/umap_.py:660: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()

# %%
from scipy.stats import truncexpon, expon
import numpy as np

# %%
export_path = "/Users/hverdier/Programs/data/models_gratin/for_tracktor/2D"
model, encoder = train_model(
    export_path= export_path,
    max_n_epochs=50,
    length_range=(5,80),
    num_workers=6,
    batch_size=256,
    dim=2,
    time_delta_range=(.003,2.5))
export_path = "/Users/hverdier/Programs/data/models_gratin/for_tracktor/3D"
model, encoder = train_model(
    export_path= export_path,
    max_n_epochs=50,
    length_range=(5,80),
    num_workers=6,
    batch_size=256,
    dim=3,
    time_delta_range=(.003,2.5))
# Out:
# Global seed set to 1
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# stage is None, strange...
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃         Test metric          ┃         DataLoader 0         ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ alpha_test_MeanAbsoluteError │      0.2741331458091736      │
# │       alpha_test_loss        │     0.35712915658950806      │
# │ model_test_MulticlassF1Score │      0.6279773712158203      │
# │       model_test_loss        │      0.496859610080719       │
# │          test_loss           │      0.7839012145996094      │
# └──────────────────────────────┴──────────────────────────────┘
# [{'alpha_test_loss': 0.35712915658950806, 'alpha_test_MeanAbsoluteError': 0.2741331458091736, 'model_test_loss': 0.496859610080719, 'model_test_MulticlassF1Score': 0.6279773712158203, 'test_loss': 0.7839012145996094}]
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/umap/parametric_umap.py:148: UserWarning: tensorflow_probability not installed or incompatible to current                 tensorflow installation. Setting global_correlation_loss_weight to zero.
#   warn(
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# ParametricUMAP(encoder=<keras.src.engine.sequential.Sequential object at 0x14871ff70>, optimizer=<keras.src.optimizers.adam.Adam object at 0x14960acd0>)
# Thu Jun 15 20:06:51 2023 Construct fuzzy simplicial set
# Thu Jun 15 20:06:51 2023 Finding Nearest Neighbors
# Thu Jun 15 20:06:51 2023 Building RP forest with 10 trees
# Thu Jun 15 20:06:53 2023 NN descent for 13 iterations
# 	 1  /  13
# 	 2  /  13
# 	 3  /  13
# 	Stopping threshold met -- exiting after 3 iterations
# Thu Jun 15 20:07:00 2023 Finished Nearest Neighbor Search
# Thu Jun 15 20:07:02 2023 Construct embedding
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/10
# 6264/6264 [==============================] - 19s 3ms/step - loss: 0.1371
# Epoch 2/10
# 6264/6264 [==============================] - 19s 3ms/step - loss: 0.1241
# Epoch 3/10
# 6264/6264 [==============================] - 19s 3ms/step - loss: 0.1229
# Epoch 4/10
# 6264/6264 [==============================] - 20s 3ms/step - loss: 0.1221
# Epoch 5/10
# 6264/6264 [==============================] - 20s 3ms/step - loss: 0.1216
# Epoch 6/10
# 6264/6264 [==============================] - 20s 3ms/step - loss: 0.1215
# Epoch 7/10
# 6264/6264 [==============================] - 20s 3ms/step - loss: 0.1210
# Epoch 8/10
# 6264/6264 [==============================] - 20s 3ms/step - loss: 0.1209
# Epoch 9/10
# 6264/6264 [==============================] - 20s 3ms/step - loss: 0.1208
# Epoch 10/10
# 6264/6264 [==============================] - 20s 3ms/step - loss: 0.1205
# 312/312 [==============================] - 0s 245us/step
# Thu Jun 15 20:10:29 2023 Finished embedding
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /Users/hverdier/Programs/data/models_gratin/for_tracktor/2D/umap/assets
# INFO:tensorflow:Assets written to: /Users/hverdier/Programs/data/models_gratin/for_tracktor/2D/umap/assets
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# Global seed set to 1
# stage is None, strange...
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/pytorch_lightning/trainer/setup.py:201: UserWarning: MPS available but not used. Set `accelerator` and `devices` using `Trainer(accelerator='mps', devices=1)`.
#   rank_zero_warn(
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Testing: 0it [00:00, ?it/s]
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃         Test metric          ┃         DataLoader 0         ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ alpha_test_MeanAbsoluteError │     0.25735360383987427      │
# │       alpha_test_loss        │      0.3259331285953522      │
# │ model_test_MulticlassF1Score │      0.6524184942245483      │
# │       model_test_loss        │      0.4762815237045288      │
# │          test_loss           │      0.7380093336105347      │
# └──────────────────────────────┴──────────────────────────────┘
# [{'alpha_test_loss': 0.3259331285953522, 'alpha_test_MeanAbsoluteError': 0.25735360383987427, 'model_test_loss': 0.4762815237045288, 'model_test_MulticlassF1Score': 0.6524184942245483, 'test_loss': 0.7380093336105347}]
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/umap/parametric_umap.py:148: UserWarning: tensorflow_probability not installed or incompatible to current                 tensorflow installation. Setting global_correlation_loss_weight to zero.
#   warn(
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# ParametricUMAP(encoder=<keras.src.engine.sequential.Sequential object at 0x14f1ae940>, optimizer=<keras.src.optimizers.adam.Adam object at 0x148b1d280>)
# Thu Jun 15 20:58:07 2023 Construct fuzzy simplicial set
# Thu Jun 15 20:58:07 2023 Finding Nearest Neighbors
# Thu Jun 15 20:58:07 2023 Building RP forest with 10 trees
# Thu Jun 15 20:58:07 2023 NN descent for 13 iterations
# 	 1  /  13
# 	 2  /  13
# 	 3  /  13
# 	Stopping threshold met -- exiting after 3 iterations
# Thu Jun 15 20:58:09 2023 Finished Nearest Neighbor Search
# Thu Jun 15 20:58:10 2023 Construct embedding
# WARNING:absl:There is a known slowdown when using v2.11+ Keras optimizers on M1/M2 Macs. Falling back to the legacy Keras optimizer, i.e., `tf.keras.optimizers.legacy.Adam`.
# Epoch 1/10
# 6257/6257 [==============================] - 18s 3ms/step - loss: 0.1427
# Epoch 2/10
# 6257/6257 [==============================] - 18s 3ms/step - loss: 0.1252
# Epoch 3/10
# 6257/6257 [==============================] - 18s 3ms/step - loss: 0.1235
# Epoch 4/10
# 6257/6257 [==============================] - 19s 3ms/step - loss: 0.1227
# Epoch 5/10
# 6257/6257 [==============================] - 18s 3ms/step - loss: 0.1221
# Epoch 6/10
# 6257/6257 [==============================] - 18s 3ms/step - loss: 0.1215
# Epoch 7/10
# 6257/6257 [==============================] - 18s 3ms/step - loss: 0.1212
# Epoch 8/10
# 6257/6257 [==============================] - 18s 3ms/step - loss: 0.1209
# Epoch 9/10
# 6257/6257 [==============================] - 18s 3ms/step - loss: 0.1208
# Epoch 10/10
# 6257/6257 [==============================] - 18s 3ms/step - loss: 0.1205
# 312/312 [==============================] - 0s 247us/step
# Thu Jun 15 21:01:22 2023 Finished embedding
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: /Users/hverdier/Programs/data/models_gratin/for_tracktor/3D/umap/assets
# INFO:tensorflow:Assets written to: /Users/hverdier/Programs/data/models_gratin/for_tracktor/3D/umap/assets
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3464: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/hverdier/miniconda3/envs/gratin-env/lib/python3.8/site-packages/numpy/core/_methods.py:192: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)

# %%
model.hparams
# Out:
# "RW_types":              ['fBM', 'LW', 'sBM', 'OU', 'CTRW']
# "dim":                   2
# "e_dim":                 6
# "gamma":                 0.98
# "latent_dim":            16
# "log_distance_features": True
# "lr":                    0.001
# "n_c":                   32
# "predict_alpha":         True
# "predict_model":         True
# "scale_types":           ['step_std', 'mean_time_step']
# "x_dim":                 6

# %%
model, encoder = load_model(export_path)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
plot_demo(model,encoder,num_workers=4,time_delta=0.03,length_range=(10,500))

# %%
import numpy as np

D = 0.1
dfs = {}
L = 15
for delta_t in [0.005,0.01,0.03,.1]:
    trajs = [np.cumsum(np.random.randn(L,2)*np.sqrt(2*D*delta_t),axis=0)  + np.random.normal(loc=0,scale=0.03,size=(L,2)) for _ in range(1000)]
    times = [np.arange(traj.shape[0])*delta_t for traj in trajs]
    dfs[delta_t] = get_predictions(model, encoder, trajs, times)

# %%
# Latent space is sensitive to exposition time
for delta_t in dfs:
    plt.scatter(dfs[delta_t]["U_1"],dfs[delta_t]["U_2"],s=3)

# %%
for delta_t in dfs:
    plt.hist(dfs[delta_t]["alpha"],histtype="step")
